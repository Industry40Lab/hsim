# %%
with open('dummy.txt', 'w') as f:
    var1 = 10
    var2 = 20
    var3 = 30

variables = locals()
print(variables['var1'], variables['var2'], variables['var3'])
# Out:
# Running cells with 'hsim (Python 3.12.9)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n hsim ipykernel --update-deps --force-reinstall'
